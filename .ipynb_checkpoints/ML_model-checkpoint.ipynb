# %%
import pandas as pd
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
import catboost
from catboost import CatBoostClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_=pd.read_csv("german_creditrisk_data.csv")

# %%
data_.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    Duration              Purpose  credit_risk
# 0         6             radio/TV            1
# 1        48             radio/TV            0
# 2        12            education            1
# 3        42  furniture/equipment            1
# 4        24                  car            0

# %%
data_.describe()
# Out:
#                Age          Job  Credit amount     Duration  credit_risk
# count  1000.000000  1000.000000    1000.000000  1000.000000  1000.000000
# mean     35.546000     1.904000    3271.258000    20.903000     0.700000
# std      11.375469     0.653614    2822.736876    12.058814     0.458487
# min      19.000000     0.000000     250.000000     4.000000     0.000000
# 25%      27.000000     2.000000    1365.500000    12.000000     0.000000
# 50%      33.000000     2.000000    2319.500000    18.000000     1.000000
# 75%      42.000000     2.000000    3972.250000    24.000000     1.000000
# max      75.000000     3.000000   18424.000000    72.000000     1.000000

# %%
data_.shape
# Out:
# (1000, 10)

# %%
pd.isnull(data_).sum()
# Out:
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# credit_risk           0
# dtype: int64

# %%
sns.pairplot(data_,kind="scatter",diag_kind="kde",dropna=True)

# %%
data_.isnull().any()
# Out:
# Age                 False
# Sex                 False
# Job                 False
# Housing             False
# Saving accounts      True
# Checking account     True
# Credit amount       False
# Duration            False
# Purpose             False
# credit_risk         False
# dtype: bool

# %% [markdown]
# <h5 style="color: blue;">Label encoded using ordinal, because it is ordered category used ordinal encoder</h5>

# %%
data_.columns = map(lambda x : x.replace(" ","_"),list(data_.columns))
data_.columns
# Out:
# Index(['Age', 'Sex', 'Job', 'Housing', 'Saving_accounts', 'Checking_account',
#        'Credit_amount', 'Duration', 'Purpose', 'credit_risk'],
#       dtype='object')

# %%
data_saving_cat=list(data_["Saving_accounts"].unique())
data_saving_cat.remove(np.nan)
data_saving_cat.append(np.nan)
data_checking_cat=list(data_["Checking_account"].unique())
data_checking_cat.remove(np.nan)
data_checking_cat.append(np.nan)
category=[data_saving_cat,data_checking_cat]
print(category)
# Out:
# [['little', 'quite rich', 'rich', 'moderate', nan], ['little', 'moderate', 'rich', nan]]

# %%
from sklearn.preprocessing import OrdinalEncoder

ord=OrdinalEncoder()
data_ord=ord.fit_transform(data_[['Checking_account','Credit_amount']])
data_[['Checking_account','Credit_amount']]=data_ord
data_
# Out:
#      Age     Sex  Job Housing Saving_accounts  Checking_account  \
# 0     67    male    2     own             NaN               0.0
# 1     22  female    2     own          little               1.0
# 2     49    male    1     own          little               NaN
# 3     45    male    2    free          little               0.0
# 4     53    male    2    free          little               0.0
# ..   ...     ...  ...     ...             ...               ...
# 995   31  female    1     own          little               NaN
# 996   40    male    3     own          little               0.0
# 997   38    male    2     own          little               NaN
# 998   23    male    2    free          little               0.0
# 999   27    male    2     own        moderate               1.0
#
#      Credit_amount  Duration              Purpose  credit_risk
# 0            142.0         6             radio/TV            1
# 1            770.0        48             radio/TV            0
# 2            390.0        12            education            1
# 3            848.0        42  furniture/equipment            1
# 4            734.0        24                  car            0
# ..             ...       ...                  ...          ...
# 995          310.0        12  furniture/equipment            1
# 996          661.0        30                  car            1
# 997           69.0        12             radio/TV            1
# 998          332.0        45             radio/TV            0
# 999          711.0        45                  car            1
#
# [1000 rows x 10 columns]

# %% [markdown]
# <h5 style="color: blue;">Using onehot encoding for sex,Pur and Housing</h5>

# %%
data_.Housing.unique().sum()
# Out:
# 'ownfreerent'

# %%
data_.Purpose.unique()
# Out:
# array(['radio/TV', 'education', 'furniture/equipment', 'car', 'business',
#        'domestic appliances', 'repairs', 'vacation/others'], dtype=object)

# %%
cols = ["Sex", "Housing","Purpose"]
dummies = pd.get_dummies(data_[cols], drop_first=True, dtype=np.int8)
dummies
data_enc = pd.concat([data_.drop(columns=["Sex", "Housing","Purpose"]), dummies], axis=1)
data_enc
# Out:
#      Age  Job Saving_accounts  Checking_account  Credit_amount  Duration  \
# 0     67    2             NaN               0.0          142.0         6
# 1     22    2          little               1.0          770.0        48
# 2     49    1          little               NaN          390.0        12
# 3     45    2          little               0.0          848.0        42
# 4     53    2          little               0.0          734.0        24
# ..   ...  ...             ...               ...            ...       ...
# 995   31    1          little               NaN          310.0        12
# 996   40    3          little               0.0          661.0        30
# 997   38    2          little               NaN           69.0        12
# 998   23    2          little               0.0          332.0        45
# 999   27    2        moderate               1.0          711.0        45
#
#      credit_risk  Sex_male  Housing_own  Housing_rent  Purpose_car  \
# 0              1         1            1             0            0
# 1              0         0            1             0            0
# 2              1         1            1             0            0
# 3              1         1            0             0            0
# 4              0         1            0             0            1
# ..           ...       ...          ...           ...          ...
# 995            1         0            1             0            0
# 996            1         1            1             0            1
# 997            1         1            1             0            0
# 998            0         1            0             0            0
# 999            1         1            1             0            1
#
#      Purpose_domestic appliances  Purpose_education  \
# 0                              0                  0
# 1                              0                  0
# 2                              0                  1
# 3                              0                  0
# 4                              0                  0
# ..                           ...                ...
# 995                            0                  0
# 996                            0                  0
# 997                            0                  0
# 998                            0                  0
# 999                            0                  0
#
#      Purpose_furniture/equipment  Purpose_radio/TV  Purpose_repairs  \
# 0                              0                 1                0
# 1                              0                 1                0
# 2                              0                 0                0
# 3                              1                 0                0
# 4                              0                 0                0
# ..                           ...               ...              ...
# 995                            1                 0                0
# 996                            0                 0                0
# 997                            0                 1                0
# 998                            0                 1                0
# 999                            0                 0                0
#
#      Purpose_vacation/others
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ..                       ...
# 995                        0
# 996                        0
# 997                        0
# 998                        0
# 999                        0
#
# [1000 rows x 17 columns]

# %%
data_enc.head()
# Out:
#    Age  Job Saving_accounts  Checking_account  Credit_amount  Duration  \
# 0   67    2             NaN               0.0          142.0         6
# 1   22    2          little               1.0          770.0        48
# 2   49    1          little               NaN          390.0        12
# 3   45    2          little               0.0          848.0        42
# 4   53    2          little               0.0          734.0        24
#
#    credit_risk  Sex_male  Housing_own  Housing_rent  Purpose_car  \
# 0            1         1            1             0            0
# 1            0         0            1             0            0
# 2            1         1            1             0            0
# 3            1         1            0             0            0
# 4            0         1            0             0            1
#
#    Purpose_domestic appliances  Purpose_education  \
# 0                            0                  0
# 1                            0                  0
# 2                            0                  1
# 3                            0                  0
# 4                            0                  0
#
#    Purpose_furniture/equipment  Purpose_radio/TV  Purpose_repairs  \
# 0                            0                 1                0
# 1                            0                 1                0
# 2                            0                 0                0
# 3                            1                 0                0
# 4                            0                 0                0
#
#    Purpose_vacation/others
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0

# %% [markdown]
# <h5>for the imputation, we need to select the right columns for the data feeding</h5>

# %%
import missingno as msno
msno.matrix(data_enc)
msno.heatmap(data_enc)
# Out:
# <Axes: >

# %%
sns.heatmap(data_enc.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 sns.heatmap(data_enc.corr())
#
# File C:\users\prasa\onedrive\desktop\projects\aws_deployment\venv\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\users\prasa\onedrive\desktop\projects\aws_deployment\venv\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# File C:\users\prasa\onedrive\desktop\projects\aws_deployment\venv\Lib\site-packages\pandas\core\internals\managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File C:\users\prasa\onedrive\desktop\projects\aws_deployment\venv\Lib\site-packages\pandas\core\internals\managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: 'little'

# %% [markdown]
# <h6>from the heatmap we can use ['Age',
#  'Job',
#  'Housing',
#  'Credit_amount',
#  'Duration',
#  'Purpose',
#  'Sex']
#  for the iterative imputation because it showing more relationship with checking accounting saving accounting</h6>

# %%
data_col=data_enc.columns

# %% [markdown]
# <h5>for imputation i am using experimental learning imputaion</h5>

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
ie=IterativeImputer()
data_imputed=ie.fit_transform(data_enc)

# %%
data_imputed=pd.DataFrame(data=data_imputed,columns=data_col)
data_imputed

# %%
pd.isnull(data_imputed).sum()

# %% [markdown]
# <h3>splitting the model as train,test,split and predicting the model</h3>

# %%
y = data_imputed['credit_risk']


x = data_imputed.drop(columns=['credit_risk'])

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,shuffle=True,stratify=y)

# %%
ca = CatBoostClassifier(iterations=500, depth=6, learning_rate=0.05, verbose=0)

# %%
categorical_cols = x_train.select_dtypes(include=['object', 'category']).columns.tolist()

print(categorical_cols)

# %%
ca.fit(
    x_train,
    y_train)

# %%
y_pred=ca.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_pred,y_test)

# %%
acc

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# %%
ordinal_cols = ['Checking_account','Saving_accounts']
ord_categories = [['low','medium','high'], ['low','medium','high']]
numeric_cols = ["Age","Job","Credit_amount","Duration"]
processor = ColumnTransformer(
    transformers=[
        ("ord", OrdinalEncoder(categories=ord_categories),ordinal_cols),
        ("nom",OneHotEncoder(drop_first=True,sparse=False),numeric_cols)
    ]
)

# %%
pipeline = Pipeline([
    ("preprocessor", processor),
    ("classifier", CatBoostClassifier(iterations=500, depth=6, learning_rate=0.05, verbose=0))
])

# %%
# Fit the pipeline
pipeline.fit(x_train, y_train)

# Predict
y_pred = pipeline.predict(x_test)
